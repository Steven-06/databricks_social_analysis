# %%
# The path as shown in your Catalog Explorer
file_path = "/Volumes/workspace/default/social_data/trending_topics_2026_synthetic.csv"

# Load the data
df = spark.read.format("csv") \
    .option("header", "true") \
    .option("inferSchema", "true") \
    .load(file_path)

# Preview the data to start cleaning
display(df)
